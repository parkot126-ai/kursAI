# %% [markdown]
# <a href="https://colab.research.google.com/github/parkot126-ai/kursAI/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   **SPIS TREŚCI**
# 1. ***Zmienne***
# 2. ***Listy***
# 3. ***Pętle***
# 4. ***Słowniki i krotki***
# 5. ***Instrukcje warunkowe***
# 6. ***Funkcje***
# 7. ***Obsługa plików***
# 8. ***Obsługa wyjątków***

# %%
licznik = 1
while licznik <= 5:
  print(liczni)
  licznik += 1
